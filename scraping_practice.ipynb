# %%
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import pandas as pd

# %%
#Get links 
squad_url = 'https://fbref.com/en/comps/23/2020-2021/2020-2021-Eredivisie-Stats'
response = requests.get(squad_url)

soup = BeautifulSoup(response.text,'html.parser')

links = []
for link in soup.find_all('a'):
    links.append(link.get("href"))

# %%
link_df = pd.DataFrame(links)
link_df.to_csv('links2.csv')

# %%
#lists to loop through
cats = ['shooting','keeper','passing','passing_types','gca','defense','possession','misc']
year_range = ['2017-2018','2018-2019','2019-2020','2020-2021','2021-2022','2022-2023']

# %%
squad_number = squad_codes['Squad_Code'][0]
print(squad_number)

# %%
range(len(squad_codes))

# %%
squad_codes['Text'][0]

# %%
#url builder

scrape_link = f"https://fbref.com/en/squads/{squad_number}/{year_range}/matchlogs/all_comps/{stats_category}/{final_detail_string}"

# %%
pages_to_scrape = []

for x in range(len(year_range)):
    for i in range(len(squad_codes)):
        for z in range(len(cats)):
            link = (f"https://fbref.com/en/squads/{squad_codes['Squad_Code'][i]}/{year_range[x]}/matchlogs/all_comps/{cats[z]}/{squad_codes['Text'][i]}")
            pages_to_scrape.append(link)

# %%
pages_to_scrape

# %%
len(pages_to_scrape)

# %%
squad_codes = pd.read_csv('big5_MLS_squad_codes.csv')

# %%
squad_codes

# %%
squad_codes['Text'][5]

# %%
squad_codes['Squad Code']

# %%
scrape_link_test = f"https://fbref.com/en/squads/{squad_codes['Squad_Code'][0]}/{year_range[5]}/matchlogs/all_comps/{cats[2]}/{squad_codes['Text'][5]}"
print(scrape_link_test)

# %%
for x in range(len(squad_codes)):
    print(f"{squad_codes['Squad Code'][x]} - {squad_codes['Squad Name'][x]}")

# %%
import time

for i in range(10):
    print("Progress: [", "="*i, " "*(9-i), "]", i+1, "/10", end="\r")
    time.sleep(3)

# %%
test_link = 'https://fbref.com/en/squads/18bb7c10/2017-2018/matchlogs/all_comps/possession/Arsenal-Match-Logs-All-Competitions'

# %%
# Test Scrape

res = requests.get(test_link)
soup = BeautifulSoup(res.text, 'html.parser')

# Find the table with the desired div id
table = soup.find('table', {'id': 'matchlogs_for'})

table_body = table.find('tbody')

rows = table_body.find_all('tr')

data = []

for row in rows:
    cols = row.find_all(['td','th'])
    cols = [col.text.strip() for col in cols]
    data.append(cols)
    
df_for = pd.DataFrame(data, columns=['Date','Time','Comp','Round','Day','Venue','Result','GF','GA','Opponent','Possession','Touches','Touches in Def Pen Area','Touches in Def 3rd','Touches in Mid 3rd','Touches in Att 3rd','Touches in Att Pen Area','Live ball touches','Attempted Take ons','Succesful Take Ons','Take on success rate','Number of times tackled during take on','% of take ons tackled','Carries','Total Carry Distance','Progressive Carrying Distance','Progressive Carries','Carries into final third','Carries into penalty area','Miscontrols','Dispossessions','Passes Received','Progressive Passes Received','Match Report'])

# %%
df_for
# Out:
#           Date   Time              Comp                Round  Day    Venue  \
# 0   2017-08-06  14:00  Community Shield  FA Community Shield  Sun  Neutral
# 1   2017-08-11  19:45    Premier League          Matchweek 1  Fri     Home
# 2   2017-08-19  17:30    Premier League          Matchweek 2  Sat     Away
# 3   2017-08-27  16:00    Premier League          Matchweek 3  Sun     Away
# 4   2017-09-09  15:00    Premier League          Matchweek 4  Sat     Home
# 5   2017-09-14  21:05         Europa Lg          Group stage  Thu     Home
# 56      L      0      1  es Atlético Madrid  ...                 2113
# 57      W      5      0             Burnley  ...                 3011
# 58      L      1      3      Leicester City  ...                 1797
# 59      W      1      0        Huddersfield  ...                 2031
#
#    Progressive Carrying Distance Progressive Carries Carries into final third  \
# 0
# 1                           1686                  31                       32
# 2                           1891                  32                       35
# 3                           1022                  15                       12
# 4                            829                  13                        9
# 5                           1486                  23                       20
# 6                            863                  11                       19
# 7
# 8                           1431                  26                       24
# 9                           1036                  17                       15
# 10                          1595                  31                       38
# 11                          1109                  25                       15
# 12                          1430                  25                       19
# 13                          1342                  29                       24
# 14
# 15                          1601                  24                       26
# 16                          1680                  32                       28
# 17                           736                  11                       11
# 18                           819                  14                       17
# 19                          1563                  36                       23
# 20                          1652                  33                       30
# 21                          1031                  14                        8
# 22                          1926                  42                       36
# 23                          1118                  23                        7
# 24                          1720                  32                       38
# 25                          1462                  29                       36
# 26                          1766                  34                       29
# 27
# 28                          1217                  26                       16
# 29                          1232                  24                       10
# 30                          1455                  25                       23
# 31                          1243                  30                       17
# 32
# 33
# 34                          1094                  23                       14
# 35                          1435                  21                       21
# 36
# 37                          1751                  18                       23
# 38                          1263                  23                       15
# 39                          1165                  20                       12
# 40                          1759                  27                       27
# 41                          1463                  24                       21
# 42
# 43                           673                   9                       15
# 44                          1578                  32                       28
# 45                           914                  16                       14
# 46                           981                  22                       12
# 47                          1322                  21                       21
# 48                          1441                  29                       18
# 49                          1050                  16                       16
# 50                          1249                  16                       24
# 51                          1004                  24                       22
# 52                          1391                  23                       19
# 53                          1594                  30                       23
# 54                          1424                  35                       20
# 55                          1187                  24                       23
# 56                          1099                  29                       15
# 57                          1875                  36                       24
# 58                           998                  28                       14
# 59                          1043                  10                       15
#
#    Carries into penalty area Miscontrols Dispossessions Passes Received  \
# 0
# 1                          7          11             14             562
# 2                          4          14             15             673
# 3                          5          12             12             463
# 4                          8          12              7             492
# 5                          6          14             14             708
# 6                          1          17             10             431
# 7
# 8                          8          22             10             564
# 9                          3           8             17             529
# 10                         6          18              7             636
# 11                         5          17             12             459
# 12                         5          11              8             510
# 13                        11          17              6             546
# 14
# 15                         3           8             10             731
# 16                         8          20              7             560
# 17                         3          17             15             395
# 18                         5          20              7             302
# 19                        14          16             12             688
# 20                         6           8              9             553
# 21                         4          11              8             735
# 22                         6          11             12             593
# 23                         7          17             16             654
# 24                         5          21             12             690
# 25                         4          16              7             635
# 26                        13          11             13             676
# 27
# 28                         8          23             17             412
# 29                         7          13             17             575
# 30                         7          11              9             566
# 31                         5          16             11             532
# 32
# 33
# 34                         9          19             21             436
# 35                         4          14             12             660
# 36
# 37                         2          10              9             854
# 38                         5          13              8             484
# 39                         1          12             10             437
# 40                         6          14             15             775
# 41                        11           8              6             521
# 42
# 43                         2          18              5             449
# 44                         7          10             16             547
# 45                         4          13              8             456
# 46                         7          13              7             438
# 47                         8          14              3             569
# 48                         2          15              8             572
# 49                         3          11              4             503
# 50                         3          12              8             623
# 51                         7          12              6             405
# 52                         3          17             14             617
# 53                        10          15              6             578
# 54                         8          10             10             718
# 55                         3          11             12             377
# 56                         3          14              7             442
# 57                        13          11             10             606
# 58                         8           8             11             408
# 59                         4          16             15             438
#
#    Progressive Passes Received  Match Report
# 0                               Match Report
# 1                           61  Match Report
# 2                           85  Match Report
# 3                           48  Match Report
# 4                           50  Match Report
# 5                           76  Match Report
# 6                           33  Match Report
# 7                               Match Report
# 8                           63  Match Report
# 9                           45  Match Report
# 10                          65  Match Report
# 11                          57  Match Report
# 12                          53  Match Report
# 13                          64  Match Report
# 14                              Match Report
# 15                          84  Match Report
# 16                          66  Match Report
# 17                          40  Match Report
# 18                          48  Match Report
# 19                          87  Match Report
# 20                          39  Match Report
# 21                          81  Match Report
# 22                          99  Match Report
# 23                          92  Match Report
# 24                          79  Match Report
# 25                          80  Match Report
# 26                          75  Match Report
# 27                              Match Report
# 28                          52  Match Report
# 29                          65  Match Report
# 30                          56  Match Report
# 31                          80  Match Report
# 32                              Match Report
# 33                              Match Report
# 34                          53  Match Report
# 35                          56  Match Report
# 36                              Match Report
# 37                          75  Match Report
# 38                          45  Match Report
# 39                          31  Match Report
# 40                          65  Match Report
# 41                          43  Match Report
# 42                              Match Report
# 43                          44  Match Report
# 44                          58  Match Report
# 45                          36  Match Report
# 46                          40  Match Report
# 47                          53  Match Report
# 48                          47  Match Report
# 49                          53  Match Report
# 50                          52  Match Report
# 51                          33  Match Report
# 52                          67  Match Report
# 53                          62  Match Report
# 54                         111  Match Report
# 55                          36  Match Report
# 56                          47  Match Report
# 57                          64  Match Report
# 58                          35  Match Report
# 59                          41  Match Report
#
# [60 rows x 34 columns]

# %%
score_columns = ['Date','Time','Comp','Round','Day','Venue','Result','GF','GA','Opponent','xG','xGA','Poss','Attendance','Captain','Formation','Referee','Match Report','Notes'
]

passing_columns = ['Time','Comp','Round','Day','Venue','Result','GF','GA','Opponent','Cmp','Att','Cmp%','TotDist','PrgDist','Shrt_Cmp','Shrt_Att','Shrt_Cmp%','Med_Cmp','Med_Att','Med_Cmp%','Lng_Cmp','Lng_Att','Lng_Cmp%','Ast','xAG','xA','KP','attacking_third_passes','18_yard_box_pass_completed','Completed_Cross','Prog_Pass','Match_Report'
]

shooting_columns = ['Time','Comp','Round','Day','Venue','Result','GF','GA','Opponent','Gls','Sh','SoT','SoT%','G/Sh','G/SoT','Dist','FK','PK','PKatt','xG','npxG','npxG/Sh','G-xG','np:G-xG','Match Report'
]

# %%
# Test against Scrape

res = requests.get(scrape_link_test)
soup = BeautifulSoup(res.text, 'html.parser')

# Find the table with the desired div id
table = soup.find('table', {'id': 'matchlogs_against'})

rows = table.find_all('tr')

data = []

for row in rows:
    cols = row.find_all('td')
    cols = [col.text.strip() for col in cols]
    data.append(cols)
    
df_against = pd.DataFrame(data, columns=['Time','Comp','Round','Day','Venue','Result','GF','GA','Opponent','Cmp','Att','Cmp%','TotDist','PrgDist','Shrt_Cmp','Shrt_Att','Shrt_Cmp%','Med_Cmp','Med_Att','Med_Cmp%','Lng_Cmp','Lng_Att','Lng_Cmp%','Ast','xAG','xA','KP','attacking_third_passes','18_yard_box_pass_completed','Completed_Cross','Prog_Pass','Match_Report'
])

# %%
df_against

# %%
for x in range(len(squad_codes)):
    print(f"{squad_codes['Squad_Code'][x]} - {squad_codes['Squad Name'][x]}")
